# %%
# Point to get across
# What is K-Means
# K Cluster Selection - Elbow Method
# K-Means Use case

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
surveyResponses = pd.read_csv('..\data\people_survey\people_survey.csv')

# %%
surveyResponses.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock           ...             Age  \
# 0      1.0  5.0   5.0                1.0           ...            20.0
# 1      2.0  3.0   5.0                4.0           ...            19.0
# 2      5.0  3.0   5.0                3.0           ...            20.0
# 3      1.0  2.0   2.0                1.0           ...            22.0
# 4      3.0  5.0   3.0                1.0           ...            20.0
#
#    Height  Weight  Number of siblings  Gender  Left - right handed  \
# ...

# %%
surveyColumns = pd.read_csv('..\data\people_survey\columns.csv')

# %%
surveyColumns
# Out:
#                                               original  \
# 0                          I enjoy listening to music.
# 1                                            I prefer.
# 2                                   Dance, Disco, Funk
# 3                                           Folk music
# 4                                              Country
# 5                                            Classical
# 6                                             Musicals
# 7                                                  Pop
# 8                                                 Rock
# 9                                     Metal, Hard rock
# 10                                                Punk
# 11                                        Hip hop, Rap
# 12                                         Reggae, Ska
# 13                                         Swing, Jazz
# 14                                         Rock n Roll
# 15                                   Alternative music
# ...
