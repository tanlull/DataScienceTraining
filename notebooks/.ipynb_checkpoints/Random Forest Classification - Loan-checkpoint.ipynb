# %% [markdown]
# # Random Forest Classification - Loan

# %%
# Points to get across
# How it works & Decision Tree - multi class model
# Feature Selection & Feature Importance  & Type of features it can take
# Light feature engineering
# Grid Search
# Imbalance Class & How it relates to business
# Use case

# %% [markdown]
# ## Company Information:
# Lending Club is a peer to peer lending company based in the United States, in which investors provide funds for potential borrowers and investors earn a profit depending on the risk they take (the borrowers credit score). Lending Club provides the "bridge" between investors and borrowers.

# %% [markdown]
# ## Let's make a classifiaction model to detect if a "new" loan will be good or bad

# %%
## Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import Data
loan = pd.read_csv('../data/prep_loan.csv', low_memory=False)
loan.head()
# Out:
#           purpose verification_status  loan_amnt  int_rate  installment grade  \
# 0     credit_card            Verified     5000.0     10.65       162.87     B
# 1             car     Source Verified     2500.0     15.27        59.83     C
# 2  small_business        Not Verified     2400.0     15.96        84.33     C
# 3           other     Source Verified    10000.0     13.49       339.31     C
# 4         wedding     Source Verified     5000.0      7.90       156.46     A
#
#   sub_grade emp_length home_ownership  annual_inc        ...          \
# 0        B2  10+ years           RENT     24000.0        ...
# 1        C4   < 1 year           RENT     30000.0        ...
# 2        C5  10+ years           RENT     12252.0        ...
# 3        C1  10+ years           RENT     49200.0        ...
# 4        A4    3 years           RENT     36000.0        ...
#
#    inq_last_6mths  open_acc  total_acc  pub_rec  revol_util  revol_bal  \
# 0             1.0       3.0        9.0      0.0        83.7    13648.0
# 1             5.0       3.0        4.0      0.0         9.4     1687.0
# 2             2.0       2.0       10.0      0.0        98.5     2956.0
# 3             1.0      10.0       37.0      0.0        21.0     5598.0
# 4             3.0       9.0       12.0      0.0        28.3     7963.0
#
#    addr_state        term loan_condition loan_condition_num
# 0          AZ   36 months           Good                  0
# 1          GA   60 months            Bad                  1
# 2          IL   36 months           Good                  0
# 3          CA   36 months           Good                  0
# 4          AZ   36 months           Good                  0
#
# [5 rows x 21 columns]

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40575 entries, 0 to 40574
# Data columns (total 21 columns):
# purpose                40575 non-null object
# verification_status    40575 non-null object
# loan_amnt              40575 non-null float64
# int_rate               40575 non-null float64
# installment            40575 non-null float64
# grade                  40575 non-null object
# sub_grade              40575 non-null object
# emp_length             40575 non-null object
# home_ownership         40575 non-null object
# annual_inc             40575 non-null float64
# dti                    40575 non-null float64
# inq_last_6mths         40575 non-null float64
# open_acc               40575 non-null float64
# total_acc              40575 non-null float64
# pub_rec                40575 non-null float64
# revol_util             40575 non-null float64
# revol_bal              40575 non-null float64
# addr_state             40575 non-null object
# term                   40575 non-null object
# loan_condition         40575 non-null object
# loan_condition_num     40575 non-null int64
# dtypes: float64(11), int64(1), object(9)
# memory usage: 6.5+ MB

# %%
# Check correlations & other visualization
sns.heatmap(loan.corr(), annot=True)

# %%
# Drop installment
loan = loan.drop(columns=['installment'])
sns.heatmap(loan.corr(), annot=True)

# %%
# Identify what information we know when initiating a loan
# purpose
# verification_status
# loan_amnt
# int_rate
# installment
# grade
# sub_grade
# emp_length
# home_ownership
# annual_inc
# dti, dti_joint
# inq_last_6mths
# mths_since_last_delinq
# open_acc / total_acc
# pub_rec
# revol_util
# revol_bal
# addr_state
# term
# issue_d
feature_selected = ['purpose', 'verification_status', 'loan_amnt', 'int_rate', 'grade', 'sub_grade', 'emp_length', 'home_ownership', 'annual_inc', 'dti', 'inq_last_6mths', 'open_acc', 'total_acc', 'pub_rec', 'revol_util', 'revol_bal', 'addr_state', 'term', 'loan_condition', 'loan_condition_num']
x_feature = ['purpose', 'verification_status', 'loan_amnt', 'int_rate', 'grade', 'sub_grade', 'emp_length', 'home_ownership', 'annual_inc', 'dti', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_util', 'revol_bal', 'addr_state', 'term']
y_feature = 'loan_condition'
loan = loan[feature_selected]
loan.head()
# Out:
#           purpose verification_status  loan_amnt  int_rate grade sub_grade  \
# 0     credit_card            Verified     5000.0     10.65     B        B2
# 1             car     Source Verified     2500.0     15.27     C        C4
# 2  small_business        Not Verified     2400.0     15.96     C        C5
# 3           other     Source Verified    10000.0     13.49     C        C1
# 4         wedding     Source Verified     5000.0      7.90     A        A4
#
#   emp_length home_ownership  annual_inc    dti  inq_last_6mths  open_acc  \
# 0  10+ years           RENT     24000.0  27.65             1.0       3.0
# 1   < 1 year           RENT     30000.0   1.00             5.0       3.0
# 2  10+ years           RENT     12252.0   8.72             2.0       2.0
# 3  10+ years           RENT     49200.0  20.00             1.0      10.0
# 4    3 years           RENT     36000.0  11.20             3.0       9.0
#
#    total_acc  pub_rec  revol_util  revol_bal addr_state        term  \
# 0        9.0      0.0        83.7    13648.0         AZ   36 months
# 1        4.0      0.0         9.4     1687.0         GA   60 months
# 2       10.0      0.0        98.5     2956.0         IL   36 months
# 3       37.0      0.0        21.0     5598.0         CA   36 months
# 4       12.0      0.0        28.3     7963.0         AZ   36 months
#
#   loan_condition  loan_condition_num
# 0           Good                   0
# 1            Bad                   1
# 2           Good                   0
# 3           Good                   0
# 4           Good                   0

# %%
# Transform -- From Cat to dummy variables
categories = ['purpose', 'verification_status', 'grade', 'sub_grade', 'emp_length', 'home_ownership', 'addr_state', 'term']
raw_model_data = pd.get_dummies(loan.copy(), columns=categories,drop_first=True)

# %%
# Scikit Learn
from sklearn.model_selection import train_test_split

X = raw_model_data.drop(columns=['loan_condition', 'loan_condition_num'],axis=1)
y = raw_model_data['loan_condition']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=600)

rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=600, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
predictions = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#         Bad       0.50      0.02      0.03      1978
#        Good       0.84      1.00      0.91     10195
#
# avg / total       0.78      0.84      0.77     12173

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[   31  1947]
#  [   31 10164]]

# %%
# What can we make from these results? 
# For Every 100 Loans 
# (Only when we predict "yes", 1880/(1880 + 10217) % will be bad loans)

# Can we use this model? 
# If yes then how? 
# If no, then what do we need to do?

# Plot the avg loan size by loan_condition
# Plot the weighted avg Int rate by loan_condition

# %%
sns.barplot('loan_condition', 'loan_amnt', data=loan, palette='tab10', ci=None)

# %%
loan.groupby(['loan_condition'])['loan_amnt'].mean()
# Out:
# loan_condition
# Bad     11828.348353
# Good    10657.060840
# Name: loan_amnt, dtype: float64

# %%
sns.barplot('loan_condition', 'int_rate', data=loan, palette='tab10', ci=None)

# %%
loan.groupby(['loan_condition'])['int_rate'].mean()
# Out:
# loan_condition
# Bad     13.922523
# Good    11.683758
# Name: int_rate, dtype: float64

# %%
# Show Feature Importance
# This might help with "how" to feature engineering
# Get Feature Columns
feature_names = raw_model_data.columns

importances = rfc.feature_importances_
std = np.std([tree.feature_importances_ for tree in rfc.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

for f in range(X.shape[1]):
    print("%s: feature importance (%f)" % (feature_names[indices[f]], importances[indices[f]]))
# Out:
# int_rate: feature importance (0.074600)
# annual_inc: feature importance (0.074462)
# revol_util: feature importance (0.073596)
# dti: feature importance (0.071321)
# revol_bal: feature importance (0.071304)
# loan_amnt: feature importance (0.062764)
# total_acc: feature importance (0.061130)
# open_acc: feature importance (0.052255)
# inq_last_6mths: feature importance (0.035292)
# addr_state_WV: feature importance (0.022608)
# home_ownership_OTHER: feature importance (0.013415)
# purpose_wedding: feature importance (0.012084)
# loan_condition_num: feature importance (0.011969)
# sub_grade_G4: feature importance (0.011831)
# purpose_vacation: feature importance (0.011228)
# addr_state_AR: feature importance (0.010906)
# addr_state_DC: feature importance (0.008236)
# purpose_other: feature importance (0.008205)
# emp_length_8 years: feature importance (0.008104)
# purpose_medical: feature importance (0.007900)
# emp_length_10+ years: feature importance (0.007734)
# sub_grade_G5: feature importance (0.007665)
# addr_state_NM: feature importance (0.007636)
# pub_rec: feature importance (0.007172)
# emp_length_3 years: feature importance (0.006984)
# loan_condition: feature importance (0.006758)
# emp_length_2 years: feature importance (0.006626)
# home_ownership_NONE: feature importance (0.006385)
# grade_B: feature importance (0.005791)
# addr_state_SD: feature importance (0.005721)
# purpose_debt_consolidation: feature importance (0.005655)
# addr_state_NE: feature importance (0.005603)
# emp_length_4 years: feature importance (0.005532)
# verification_status_Verified: feature importance (0.005306)
# emp_length_5 years: feature importance (0.005257)
# addr_state_DE: feature importance (0.005192)
# grade_C: feature importance (0.005074)
# verification_status_Source Verified: feature importance (0.004870)
# addr_state_IA: feature importance (0.004846)
# emp_length_6 years: feature importance (0.004703)
# addr_state_OK: feature importance (0.004189)
# addr_state_TX: feature importance (0.004166)
# purpose_home_improvement: feature importance (0.004099)
# addr_state_LA: feature importance (0.004015)
# grade_D: feature importance (0.004010)
# addr_state_KY: feature importance (0.003965)
# addr_state_NJ: feature importance (0.003868)
# addr_state_NV: feature importance (0.003780)
# sub_grade_B5: feature importance (0.003740)
# addr_state_VA: feature importance (0.003696)
# emp_length_7 years: feature importance (0.003653)
# sub_grade_B2: feature importance (0.003616)
# sub_grade_B3: feature importance (0.003525)
# sub_grade_B1: feature importance (0.003502)
# addr_state_MS: feature importance (0.003491)
# addr_state_AL: feature importance (0.003439)
# sub_grade_B4: feature importance (0.003360)
# addr_state_MI: feature importance (0.003320)
# sub_grade_C1: feature importance (0.003256)
# sub_grade_D1: feature importance (0.003049)
# addr_state_CA: feature importance (0.002999)
# sub_grade_C5: feature importance (0.002986)
# addr_state_AZ: feature importance (0.002959)
# addr_state_MD: feature importance (0.002903)
# purpose_house: feature importance (0.002831)
# sub_grade_C2: feature importance (0.002807)
# sub_grade_A5: feature importance (0.002800)
# sub_grade_C3: feature importance (0.002779)
# sub_grade_D2: feature importance (0.002727)
# purpose_major_purchase: feature importance (0.002703)
# purpose_small_business: feature importance (0.002702)
# addr_state_ME: feature importance (0.002611)
# sub_grade_D3: feature importance (0.002502)
# sub_grade_A2: feature importance (0.002438)
# sub_grade_A3: feature importance (0.002404)
# sub_grade_D4: feature importance (0.002398)
# sub_grade_A4: feature importance (0.002287)
# purpose_credit_card: feature importance (0.002210)
# addr_state_VT: feature importance (0.002203)
# addr_state_OH: feature importance (0.002156)
# grade_E: feature importance (0.002098)
# sub_grade_D5: feature importance (0.002084)
# sub_grade_C4: feature importance (0.001987)
# purpose_educational: feature importance (0.001924)
# sub_grade_E2: feature importance (0.001877)
# addr_state_PA: feature importance (0.001837)
# home_ownership_OWN: feature importance (0.001824)
# addr_state_KS: feature importance (0.001780)
# sub_grade_E1: feature importance (0.001769)
# grade_G: feature importance (0.001650)
# sub_grade_F3: feature importance (0.001565)
# addr_state_IN: feature importance (0.001527)
# addr_state_NH: feature importance (0.001515)
# addr_state_NY: feature importance (0.001419)
# addr_state_OR: feature importance (0.001417)
# purpose_renewable_energy: feature importance (0.001403)
# addr_state_NC: feature importance (0.001386)
# sub_grade_E3: feature importance (0.001348)
# grade_F: feature importance (0.001319)
# addr_state_TN: feature importance (0.001232)
# addr_state_IL: feature importance (0.001200)
# sub_grade_E4: feature importance (0.001181)
# sub_grade_E5: feature importance (0.001181)
# sub_grade_F1: feature importance (0.001016)
# sub_grade_F2: feature importance (0.000992)
# addr_state_FL: feature importance (0.000978)
# home_ownership_RENT: feature importance (0.000949)
# emp_length_< 1 year: feature importance (0.000902)
# addr_state_WA: feature importance (0.000812)
# addr_state_CO: feature importance (0.000791)
# purpose_moving: feature importance (0.000721)
# sub_grade_F5: feature importance (0.000673)
# sub_grade_G2: feature importance (0.000672)
# sub_grade_F4: feature importance (0.000651)
# addr_state_MO: feature importance (0.000581)
# addr_state_RI: feature importance (0.000570)
# addr_state_CT: feature importance (0.000520)
# sub_grade_G1: feature importance (0.000439)
# addr_state_UT: feature importance (0.000424)
# sub_grade_G3: feature importance (0.000421)
# addr_state_ID: feature importance (0.000369)
# addr_state_MN: feature importance (0.000330)
# addr_state_MT: feature importance (0.000203)
# addr_state_SC: feature importance (0.000195)
# addr_state_WI: feature importance (0.000162)
# addr_state_GA: feature importance (0.000124)
# addr_state_HI: feature importance (0.000077)
# emp_length_9 years: feature importance (0.000041)
# addr_state_MA: feature importance (0.000001)
